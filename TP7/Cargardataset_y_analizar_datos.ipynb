# %% [markdown]
# <a href="https://colab.research.google.com/github/Berlinzm/Talento-TECH/blob/main/TP7/Cargardataset_y_analizar_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sklearn
import seaborn as sns

# %%
df = pd.read_csv("IceCreamData.csv")
df
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
import pandas as pd
import sklearn
import seaborn as sns

# %%
df = pd.read_csv("titanic_original.csv")
df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
import pandas as pd
import sklearn
import seaborn as sns

# %%
df = pd.read_excel("Coffee Shop Sales.xlsx")
df

# %%
import pandas as pd
import sklearn
import seaborn as sns

# %%
df = customers = pd.read_excel("Importaciones_Exportaciones.xlsx", sheet_name="Industriales")
df_customers

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("Importaciones_Exportaciones.xlsx", sheet_name="Industriales")
